# %% [markdown]
# ## Chapter 6. 데이터 정제하기

# %%
# 버전 안내
import pandas as pd
print(f'교재 권장 버전: Pandas 2.2.2')
print(f'현재 실행 버전: Pandas {pd.__version__}')
# Out:
# 교재 권장 버전: Pandas 2.2.2
# 현재 실행 버전: Pandas 2.2.2

# %% [markdown]
# ### 6.1. 데이터 정제하기 입문

# %% [markdown]
# ####6.1.1. 데이터 분석 과정 소개
#
# <img src=https://i.postimg.cc/MT2jy40f/06-01-deiteo-bunseog-gwajeong.jpg, width=600>

# %% [markdown]
# #### 6.1.2. 데이터 정제하기란?
#
# 📌 데이터 정제하기
#
#   - 데이터 분석 전에 **데이터 품질을 개선하는 과정**
#   - 분석 결과의 **정확도와 신뢰도**를 높이는 필수 단계
#
# 📌 주요 작업
#
#   - **필터링**: 특정 조건을 만족하는 데이터만 추출 → 필요한 범위로 좁혀 효율성 향상
#   - **결측값 처리**: 누락된 값 제거 또는 대체
#   - **이상치 처리**: 일반적 경향에서 벗어난 값 제거 또는 수정
#   - **중복 제거**: 동일 데이터가 여러 번 기록된 경우 제거
#   - **자료형 변환**: 잘못 지정된 자료형을 올바르게 변환 - 예: 수치형 데이터가 문자열로 저장된 경우 → 연산 불가 → 자료형 변환 필요

# %% [markdown]
# ### 6.2. 정렬

# %% [markdown]
# #### 6.2.1. 단일 열을 기준으로 정렬하기(sort_values)
#
# <img src=https://i.postimg.cc/vTvqR5HF/image.png, width=600>
#
# ⭐ 판다스 `sort_values`
#
# 데이터 프레임이나 시리즈의 정렬을 수행하는 함수
#
# <br>
#
#
# ⭐ `sort_values` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.sort_values(by, ascending=True)
# ```
#
# - **by**: 정렬의 기준이 될 열을 지정한다. 복수라면 리스트로 묶어 입력한다.
# - **ascending**: 정렬 방식을 오름차순 또는 내림차순으로 지정한다. 기본값은 오름차순이다.
#
# <br>

# %%
# 코드 6-1. 정렬 실습 예제 코드
import pandas as pd
data1 = [[60, 84, 80, 19], [77, 62, 95, 17], [61, 84, 72, 15], [75, 65, 95, 18]]
cols = ['국어', '영어', '수학', '나이']
df1 = pd.DataFrame(data1, index=list('ABCD'), columns=cols)
df1
# Out:
#    국어  영어  수학  나이
# A  60  84  80  19
# B  77  62  95  17
# C  61  84  72  15
# D  75  65  95  18

# %%
# 코드 6-2. 국어 열을 기준으로 오름차순으로 정렬하기
df1.sort_values('국어')
# Out:
#    국어  영어  수학  나이
# A  60  84  80  19
# C  61  84  72  15
# D  75  65  95  18
# B  77  62  95  17

# %%
# 코드 6-3. 함수를 적용해도 원본 df1이 변경되는 것은 아니다.
df1
# Out:
#    국어  영어  수학  나이
# A  60  84  80  19
# B  77  62  95  17
# C  61  84  72  15
# D  75  65  95  18

# %% [markdown]
# #### 6.2.2. 오름차순과 내림차순
#
# 📌 매개변수 `ascending`으로 방향 지정
# - `True` → 오름차순 (기본값)
# - `False` → 내림차순
# - **Tip**: ascending의 뜻이 오름차순, 알파벳 A부터 시작하는 정렬로 쉽게 연상

# %%
# 코드 6-4. 국어 열을 기준으로 내림차순으로 정렬하기
df1.sort_values('국어', ascending=False)
# Out:
#    국어  영어  수학  나이
# B  77  62  95  17
# D  75  65  95  18
# C  61  84  72  15
# A  60  84  80  19

# %% [markdown]
# #### 6.2.3. 복수의 열을 기준으로 정렬하기
#
# - `by`에 리스트 입력 → 복수의 열을 기준으로 정렬
# - `ascending`도 리스트 입력 → 각 열마다 방향 지정

# %%
# 코드 6-5. 영어 열로 오름차순 정렬하되, 동점일 때는 나이 열로 오름차순 정렬
df1.sort_values(['영어', '나이'])
# Out:
#    국어  영어  수학  나이
# B  77  62  95  17
# D  75  65  95  18
# C  61  84  72  15
# A  60  84  80  19

# %%
# 코드 6-6. 영어 열로 내림차순 정렬하되, 동점일 때는 나이 열로 오름차순으로 정렬
df1.sort_values(['영어', '나이'], ascending=[False, True])
# Out:
#    국어  영어  수학  나이
# C  61  84  72  15
# A  60  84  80  19
# D  75  65  95  18
# B  77  62  95  17

# %% [markdown]
# #### 6.2.4. 인덱스나 컬럼즈를 기준으로 정렬하기(sort_index)
#
# <img src=https://i.postimg.cc/ht892Kjd/image.png, width=600>
#
# ⭐ 판다스 `sort_index`
#
# 인덱스나 컬럼즈를 기준으로 정렬을 수행하는 함수
#
# <br>
#
# ⭐ sort_index 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.sort_index(axis=0, level=None, ascending=True)
# ```
# - **axis**: 인덱스가 기준인지 컬럼즈가 기준인지 지정한다.
#
# - **level**: 멀티 인덱스를 보유할 때 정렬의 기준이 되는 레벨을 지정한다.
# - **ascending**: 정렬 방식을 오름차순 또는 내림차순으로 지정한다.
#
# <br>

# %%
# 코드 6-7. 인덱스를 기준으로 알파벳 역순으로 정렬
df1.sort_index(ascending=False)
# Out:
#    국어  영어  수학  나이
# D  75  65  95  18
# C  61  84  72  15
# B  77  62  95  17
# A  60  84  80  19

# %% [markdown]
# ### 6.3. 필터링

# %% [markdown]
# #### 6.3.1. 불리언 인덱싱이란?
#
# 📌 불리언 인덱싱의 원리
#
# <img src=https://i.postimg.cc/Rhr7Phcs/image.png, width=600>
#
# 📌 실질적 활용
#
# - 비교 연산 결과인 **불 시리즈**를 인덱싱에 사용
#
# - 원하는 조건에 맞는 행만 선택 → **필터링 결과**를 얻음
#
#   ```python
#   df1[df1['국어'] < 70]   # 국어 성적이 70 미만인 행만 선택
#   ```

# %% [markdown]
# #### 6.3.2. 단일 요건 불리언 인덱싱
#
# [표 6-1] 불리언 인덱싱을 수행하는 인덱서
#
# | 대상            | 사용 가능한 인덱서        |
# |-----------------|---------------------------|
# | 행              | `[]`, `loc`               |
# | 열              | `loc`                     |
# | 행 + 열 동시에    | `loc`                     |

# %%
# 코드 6-8. 국어 점수가 70점보다 낮은 행을 필터링
df1.loc[df1['국어'] < 70]
df1[df1['국어'] < 70]
# Out:
#    국어  영어  수학  나이
# A  60  84  80  19
# C  61  84  72  15

# %%
# 코드 6-9. 조건문도 불 시리즈이기 때문에 변수로 지정할 수 있다.
cond1 = df1['국어'] < 70
df1[cond1]
# Out:
#    국어  영어  수학  나이
# A  60  84  80  19
# C  61  84  72  15

# %%
# 코드 6-10. 국어 점수가 70점보다 낮은 행의 국어, 수학 열만 필터링
df1.loc[df1['국어'] < 70, ['국어', '수학']]
# Out:
#    국어  수학
# A  60  80
# C  61  72

# %%
# 코드 6-11. A가 80점 이상 받은 과목의 전체 성적만 필터링
df1.loc[:, df1.loc['A'] >= 80]
# Out:
#    영어  수학
# A  84  80
# B  62  95
# C  84  72
# D  65  95

# %% [markdown]
# #### 6.3.3. 다중 요건 불리언 인덱싱
#
# - 여러 조건을 동시에 적용할 때는 **반드시 비트 연산자 `&`, `|`, `~`** 사용
#
# - 각 조건은 괄호 `( )`로 묶어야 정확하게 동작

# %%
# 코드 6-12. 국어 점수가 70점보다 낮으면서 수학 점수가 75점보다 높은 행 필터링
df1[(df1['국어'] < 70) & (df1['수학'] > 75) ]
# Out:
#    국어  영어  수학  나이
# A  60  84  80  19

# %%
# 코드 6-13. 코드 6-12의 조건문을 변수로 지정하면 가독성이 향상된다.
cond1 = df1['국어'] < 70
cond2 = df1['수학'] > 75
df1[cond1 & cond2]
# Out:
#    국어  영어  수학  나이
# A  60  84  80  19

# %% [markdown]
# #### 6.3.4. 불(bool) 자료형 객체를 생성하는 함수
#
# [표 6-2] 불 자료형 객체를 생성하는 다양한 함수
#
# | 함수 | 기능 |
# | :--- | :--- |
# | **`isna`**, **`isnull`** | 값이 `NaN`이면 `True`, 아니면 `False`를 반환 |
# | **`notna`**, **`notnull`** | 값이 `NaN`이면 `False`, 아니면 `True`를 반환 |
# | **`isin`** | 지정한 리스트나 값에 포함되면 `True`, 아니면 `False`를 반환 |
# | **`between`** | 두 값 사이(경계 포함)에 존재하면 `True`, 아니면 `False`를 반환 |
# | **`duplicated`** | 데이터가 중복이면 `True`, 아니면 `False`를 반환 |
#
#
# <br>
#
# <img src=https://i.postimg.cc/xTGdN8q1/image.png, width=600>
#
#
# ⭐ 판다스 `isna`
#
# 데이터 프레임이나 시리즈의 결측값(null)을 확인하는 함수
#
# <br>
#
# 📌 NaN의 탐지
#
# - NaN은 자기 자신과도 같지 않으므로 `==` 비교 불가
# - 반드시 `isna()` / `isnull()`로 탐지해야 함

# %%
# 코드 6-14. NaN은 NaN과 같지 않다.
float('nan') == float('nan')
# Out:
# False

# %%
# 코드 6-15. 실습 예제 코드
import pandas as pd
data2 = {'반': ['1반', '4반', '5반', '2반', '1반', '3반'],
         '국어': [60, 77, 61, 75, 92, 90],
         '영어': [84, 62, 84, 65, 81, 90],
         '수학': [80, float('nan'), 72, 95, float('nan'), 81]}
df2 = pd.DataFrame(data2)
df2
# Out:
#     반  국어  영어    수학
# 0  1반  60  84  80.0
# 1  4반  77  62   NaN
# 2  5반  61  84  72.0
# 3  2반  75  65  95.0
# 4  1반  92  81   NaN
# 5  3반  90  90  81.0

# %%
# 코드 6-16. 수학 열에서 NaN을 확인
df2['수학'].isna()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# Name: 수학, dtype: bool

# %%
# 코드 6-17. 수학 열에서 NaN의 개수를 확인
df2['수학'].isna().sum()
# Out:
# np.int64(2)

# %%
# 코드 6-18. 수학 열이 NaN이 아니거나 국어가 90점이상인 데이터를 필터링
cond3 = ~df2['수학'].isna() # 수학 열이 NaN이 아니다.
cond4 = df2['국어'] >= 90 # 국어 열이 90 이상이다.
df2[cond3 | cond4]
# Out:
#     반  국어  영어    수학
# 0  1반  60  84  80.0
# 2  5반  61  84  72.0
# 3  2반  75  65  95.0
# 4  1반  92  81   NaN
# 5  3반  90  90  81.0

# %% [markdown]
# <img src=https://i.postimg.cc/NjMKHXVx/image.png, width=600>
#
# ⭐ 판다스 `isin`
#
# 데이터 프레임이나 시리즈의 각 셀의 값이 특정 배열에 포함되는지 여부 확인하는 함수
#
# <br>
#
# ⭐ `isin` 함수의 주요 매개변수와 인수, 기본값
# ```python
# df.isin(values)
# ```
#
# - **values**: 포함 여부를 확인할 기준 배열을 입력한다.
#
# <br>

# %%
# 코드 6-19. 1반, 2반, 3반 중 하나에 속하는 데이터만 필터링
cond5 = df2['반'].isin(['1반', '2반', '3반'])
df2[cond5]
# Out:
#     반  국어  영어    수학
# 0  1반  60  84  80.0
# 3  2반  75  65  95.0
# 4  1반  92  81   NaN
# 5  3반  90  90  81.0

# %% [markdown]
# <img src=https://i.postimg.cc/pTpNQWvq/image.png, width=600>
#
# ⭐ 판다스 `between`
#
# 시리즈의 각 셀이 주어진 두 값 사이에 존재하는지 확인하는 함수
#
# <br>
#
# ⭐ `between` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# s.between(left, right, inclusive='both')
# ```
#
# - **left**, **right**: 좌측 경계와 우측 경계를 각각 입력한다.
# - **inclusive**: 경계의 포함 여부를 지정한다. 기본값은 'both'이고 양쪽 경계가 모두 포함된다.
#
# <br>

# %% [markdown]
# #### 6.3.5. 특정 열의 값을 기준으로 데이터의 일부만 가져오기(nlargest, nsmallest)
#
# <img src=https://i.postimg.cc/x8B9Nkb5/image.png, width=600>
#
# ⭐ 판다스 `nlargest`, `nsmallest` 함수
#
# 특정 열의 값을 기준으로 데이터의 일부만 가져오는 함수.
#
# `nlargest` 함수는 기준 열의 값이 높은 순으로 요구하는
# 행만큼 가져오고, `nsmallest` 함수는 기준 열의 값이 낮은 순으로 요구하는 행만큼 가져온다.
#
# <br>
#
# ⭐ `nlargest` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.nlargest(n, columns, keep='first')
# ```
#
# - **n**: 상위 몇 개의 행을 가져올지 정수로 지정한다.
# - **columns**: 정렬 기준이 되는 열을 지정한다.
# - **keep**: 동점이 존재할 때, 어떤 행을 가져올지 결정한다. 기본값은 첫 행만 가져오는 'first'이며, 'last' 또는 'all'
# 도 지정이 가능하다.
#
# ⭐ `nsmallest` 함수의 매개변수도 동일하다.
#
# <br>
#
# [표 6-3] `nsmallest`와 `nlargest`의 매개변수 `keep`
#
# | keep | 기능 |
# | :--- | :--- |
# | **`'first'`** | 동점인 행 중에 가장 첫 행을 가져온다. (기본값) |
# | **`'last'`** | 동점인 행 중에 가장 마지막 행을 가져온다. |
# | **`'all'`** | 동점인 행은 모두 가져온다. |
#
# <br>

# %%
# 코드 6-20. 국어 점수가 하위인 4명의 데이터만 필터링
df2.nsmallest(4, columns='국어')
# Out:
#     반  국어  영어    수학
# 0  1반  60  84  80.0
# 2  5반  61  84  72.0
# 3  2반  75  65  95.0
# 1  4반  77  62   NaN

# %%
# 코드 6-21. 영어 점수가 상위인 2명의 데이터 추출(동점자는 모두 추출)
df2.nlargest(2, columns='영어', keep='all')
# Out:
#     반  국어  영어    수학
# 5  3반  90  90  81.0
# 0  1반  60  84  80.0
# 2  5반  61  84  72.0

# %% [markdown]
# #### 6.3.6. 무작위로 데이터 추출하기(sample)
#
# ⭐ 판다스 `sample` 함수
#
# 데이터 프레임에서 무작위로 행을 추출하는 함수
#
# <br>
#
# ⭐ `sample` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.sample(n=None, frac=None, random_state=None)
# ```
#
# - **n**: 추출할 행의 개수를 정수로 지정한다. 매개변수 `frac`과 동시 사용할 수 없다.
# - **frac**: 추출할 비율을 0과 1 사이의 실수로 지정한다. 매개변수 `n`과 동시에 사용할 수 없다.
# - **random_state**: 난수 고정을 위해 시드를 지정한다.
#
# <br>

# %%
# 코드 6-22. df2에서 무작위로 3명의 데이터 추출
df2.sample(3) # 시행마다 다른 결과가 반환된다.
# Out:
#     반  국어  영어    수학
# 5  3반  90  90  81.0
# 0  1반  60  84  80.0
# 1  4반  77  62   NaN

# %%
# 코드 6-23. df2 전체를 랜덤하게 재배열(난수 고정)
df2.sample(frac=1, random_state=20)
# Out:
#     반  국어  영어    수학
# 1  4반  77  62   NaN
# 4  1반  92  81   NaN
# 0  1반  60  84  80.0
# 5  3반  90  90  81.0
# 2  5반  61  84  72.0
# 3  2반  75  65  95.0

# %% [markdown]
# ### 엑셀 예제 4. OECD 국가 GDP 데이터에서 원하는 데이터 추출하기

# %%
# 코드 6-24. OECD 국가 GDP 통계 엑셀 파일에서 데이터 프레임 불러오기
import pandas as pd
pd.options.display.max_rows = 6 # 6행까지만 출력 코드
url1 = 'https://github.com/panda-kim/book1/blob/main/08GDP.xlsx?raw=true'
df_gdp = pd.read_excel(url1)
df_gdp
# Out:
#       국가     대륙    장래인구  GDP(10억$)  1인당 GDP($)  성장률(%)     수출     수입
# 0     한국    아시아   51709     1651.0       31929     2.2  542.2  503.3
# 1   이스라엘    아시아    8519      394.7       43589     3.5   51.9   75.7
# 2     일본    아시아  126860     5064.9       40113     0.3  705.7  721.1
# ..   ...    ...     ...        ...         ...     ...    ...    ...
# 35    영국     유럽   67530     2830.8       42354     1.4  443.7  622.6
# 36    호주  오세아니아   25203     1396.6       55057     2.2  271.0  154.0
# 37  뉴질랜드  오세아니아    4783      209.1       41999     1.6   39.5   42.4
#
# [38 rows x 8 columns]

# %%
# 코드 6-25. 1인당 GPD가 8만 달러 이상인 데이터 추출
cond1 = df_gdp['1인당 GDP($)'] > 80000
df_gdp[cond1]
# Out:
#        국가  대륙  장래인구  GDP(10억$)  1인당 GDP($)  성장률(%)     수출     수입
# 21   아일랜드  유럽  4882      398.6       80779     5.6  169.6  100.8
# 25  룩셈부르크  유럽   616       71.1      114685     2.3   14.8   23.0
# 34    스위스  유럽  8591      731.5       85300     1.1  313.9  277.8

# %%
# 코드 6-26. 아시아, 남미, 오세아니아의 데이터만 추출
cond2 = df_gdp['대륙'].isin(['아시아', '남미', '오세아니아'])
df_gdp[cond2]
# Out:
#        국가     대륙    장래인구  GDP(10억$)  1인당 GDP($)  성장률(%)     수출     수입
# 0      한국    아시아   51709     1651.0       31929     2.2  542.2  503.3
# 1    이스라엘    아시아    8519      394.7       43589     3.5   51.9   75.7
# 2      일본    아시아  126860     5064.9       40113     0.3  705.7  721.1
# ..    ...    ...     ...        ...         ...     ...    ...    ...
# 9   코스타리카     남미    5048       64.0       12670     2.2   11.9   17.6
# 36     호주  오세아니아   25203     1396.6       55057     2.2  271.0  154.0
# 37   뉴질랜드  오세아니아    4783      209.1       41999     1.6   39.5   42.4
#
# [9 rows x 8 columns]

# %%
# 코드 6-27. GDP 상위 3개 국가 데이터 추출
df_gdp.nlargest(3, columns='GDP(10억$)')
# Out:
#     국가   대륙    장래인구  GDP(10억$)  1인당 GDP($)  성장률(%)      수출      수입
# 6   미국  북중미  329065    21433.2       65280     2.2  1643.1  2497.5
# 2   일본  아시아  126860     5064.9       40113     0.3   705.7   721.1
# 17  독일   유럽   83517     3861.1       46468     0.6  1489.4  1234.0

# %% [markdown]
# ### 6.4. 결측값 처리하기 1
#
# 📌 **결측값(Missing Value)**
#
# - 데이터셋에서 값이 **누락**되거나 **존재하지 않는 상태**
#
# - 판다스에서는 주로 **NaN(Not a Number)** 으로 표현
#
# - 결측값 처리
#   - **탐지**: `isna`, `isnull`
#   - **삭제**: `dropna`
#   - **대체**: `fillna`

# %% [markdown]
# #### 6.4.1. 결측값 확인하기(isna)
#
# <img src=https://i.postimg.cc/xTGdN8q1/image.png, width=600>
#
#
# ⭐ 판다스 `isna`
#
# 데이터 프레임이나 시리즈의 결측값(null)을 확인하는 함수
#
# <br>
#
# 📌 NaN의 탐지
#
# - NaN은 자기 자신과도 같지 않으므로 `==` 비교 불가
# - 반드시 `isna()` / `isnull()`로 탐지해야 함

# %%
# 코드 6-28. 결측값 처리 실습 예제 코드
import pandas as pd
data = [[88, 66, None], [None, None, 69], [69, 82, None], [71, 89, 98]]
df = pd.DataFrame(data, index=list('ABCD'), columns=['국어', '영어', '수학'])
df
# Out:
#      국어    영어    수학
# A  88.0  66.0   NaN
# B   NaN   NaN  69.0
# C  69.0  82.0   NaN
# D  71.0  89.0  98.0

# %%
# 코드 6-29. df의 각 열에 결측값이 얼마나 존재하는지 확인
df.isna().sum()
# Out:
# 국어    1
# 영어    1
# 수학    2
# dtype: int64

# %% [markdown]
# #### 6.4.2. 결측값을 포함한 데이터 삭제하기(dropna)
#
# <img src=https://i.postimg.cc/PJ5Bfd3S/image.png, width=600>
#
# ⭐ 판다스 `dropna`
#
# 결측값(null)이 있는 열이나 행을 삭제하는 함수
#
# <br>
#
# ⭐ `dropna` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.dropna(axis=0, how='any', subset=None)
# ```
#
# - **axis**: 행을 삭제하는지 열을 삭제하는지 지정한다. 기본값은 0이고 결측값이 존재하는 행을 삭제한다.
# - **how**: 어떤 기준으로 NaN을 보유한 열이나 행을 어떻게 삭제할지 지정한다. 'any'는 하나라도 NaN이 존재하
# 면 삭제하고, 'all'은 모두 NaN일 때 삭제한다.
# - **subset**: 지정된 열에 NaN이 존재할 때만 삭제한다.
# <br>

# %%
# 코드 6-30. NaN이 존재하는 행을 모두 삭제
df.dropna()
# Out:
#      국어    영어    수학
# D  71.0  89.0  98.0

# %%
# 코드 6-31. 수학 열에 NaN이 존재하는 행만 삭제
df.dropna(subset='수학')
# Out:
#      국어    영어    수학
# B   NaN   NaN  69.0
# D  71.0  89.0  98.0

# %% [markdown]
# #### 6.4.3. 결측값 대체하기(fillna)
#
# <img src=https://i.postimg.cc/B6LmmtVY/image.png, width=600>
#
# ⭐ 판다스 `fillna`
#
# 결측값을 지정한 값으로 대체하는 함수
#
# ⭐ `fillna` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.fillna(value=None)
# ```
#
# - **value**: NaN을 대체할 값을 지정한다. 입력하는 값의 종류와 함수를 적용하는 객체에 따라 다양한 방식으로 대
# 체된다.
#
# <br>
#
# [표 6-4] fillna 함수에 입력되는 대상에 따른 대체 방식
#
# | value 입력 대상 | 시리즈(Series)에 적용 시 | 데이터프레임(DataFrame)에 적용 시 |
# | :--- | :--- | :--- |
# | **단일 값 (스칼라)** | 단일 값으로 모든 `NaN`을 대체 | 단일 값으로 모든 `NaN`을 대체 |
# | **시리즈 (혹은 딕셔너리)** | 인덱스가 동일한 값으로 `NaN`을 대체 | 브로드 캐스팅|
# | **데이터프레임** | **불가능** | 인덱스와 컬럼즈가 모두 동일한 위치의 값으로 `NaN`을 대체 |
#
# <br>

# %%
# 코드 6-32. df의 NaN을 0으로 대체
df.fillna(0)
# Out:
#      국어    영어    수학
# A  88.0  66.0   0.0
# B   0.0   0.0  69.0
# C  69.0  82.0   0.0
# D  71.0  89.0  98.0

# %%
# 코드 6-33. 수학 열의 결측값을 국어 열로 대체
df['수학'].fillna(df['국어'])
# Out:
# A    88.0
# B    69.0
# C    69.0
# D    98.0
# Name: 수학, dtype: float64

# %%
# 코드 6-34. 영어 열은 0, 수학 열은 30으로 결측값 대체
df.fillna({'영어': 0, '수학': 30})
# Out:
#      국어    영어    수학
# A  88.0  66.0  30.0
# B   NaN   0.0  69.0
# C  69.0  82.0  30.0
# D  71.0  89.0  98.0

# %%
# 코드 6-35. 과목별 최저점으로 NaN을 대체
df.fillna(df.min())
# Out:
#      국어    영어    수학
# A  88.0  66.0  69.0
# B  69.0  66.0  69.0
# C  69.0  82.0  69.0
# D  71.0  89.0  98.0

# %% [markdown]
# ### 6.5. 이상치와 중복 데이터 처리

# %% [markdown]
# #### 6.5.1. 이상치 처리하기(clip)
#
# <img src=https://i.postimg.cc/23pMQnjd/image.png, width=600>
#
# ⭐ 판다스 `clip`
#
# 상한선이나 하한선으로 임곗값을 적용해 이상치(outlier)를 처리하는 함수
#
#
# ⭐ `clip` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.clip(lower=None, upper=None)
# ```
#
# - **lower**: 최솟값으로 적용할 임곗값을 입력한다. 배열을 입력하면 열마다 다르게 적용한다.
# - **upper**: 최댓값으로 적용할 임곗값을 입력한다. 배열을 입력하면 열마다 다르게 적용한다.
#
# <br>

# %%
# 코드 6-36. clip 함수 실습 예제 코드
import pandas as pd
data1 = [[89, 4, 74], [29, 46, 83], [40, 19, 60], [29, 91, 76]]
df1 = pd.DataFrame(data1, index=list('ABCD'), columns=['국어', '영어', '수학'])
df1
# Out:
#    국어  영어  수학
# A  89   4  74
# B  29  46  83
# C  40  19  60
# D  29  91  76

# %%
# 코드 6-37. 상한선과 하한선으로 임곗값을 각각 20과 80으로 적용
df1.clip(lower=20, upper=80)
# Out:
#    국어  영어  수학
# A  80  20  74
# B  29  46  80
# C  40  20  60
# D  29  80  76

# %% [markdown]
# #### 6.5.2. 중복 데이터 확인 및 제거(duplicated, drop_duplicates)
#
# <img src=https://i.postimg.cc/2jJ1pyXF/image.png, width=600>
#
# ⭐ 판다스 `duplicated` 함수와 `drop_duplicates` 함수
#
# 중복 데이터를 확인하거나 삭제하는 함수
#
# <br>
#
# ⭐ `drop_duplicates` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.drop_duplicates(subset=None, keep='first')
# ```
#
# - **subset**: 중복을 확인할 열을 지정한다. 기본값은 모든 열의 값이 동일할 때 중복으로 처리된다.
# - **keep**: 중복일 때 어떤 행을 유지할지 지정한다. 'first'가 기본값이며, 동일한 데이터가 존재하더라도 첫 번째 행은 유지하고 두 번째 행부터 중복 데이터로 처리한다.
# <br>
#
#
#
# ⭐ `duplicated` 함수의 매개변수도 `drop_duplicates` 함수와 동일하다.
#
# <br>
#
# [표 6-5] 매개변수 keep과 중복 처리 방식
#
# | 매개변수 설정 | 중복 처리 방식 |
# | :--- | :--- |
# | **`keep='first'`** | 동일한 데이터 중에서 첫 번째 데이터를 제외하고 모두 중복으로 처리한다. (기본값) |
# | **`keep='last'`** | 동일한 데이터 중에서 마지막 데이터를 제외하고 모두 중복으로 처리한다. |
# | **`keep=False`** | 동일한 데이터는 모두 중복으로 처리한다. (유일한 값만 남김) |
#
# <br>

# %%
# 코드 6-38. 중복 데이터 처리 실습 예제 코드
import pandas as pd
data = {'회차': [1, 1, 1, 2, 2],
        '이름': ['김판다', '김판다', '강승주', '조민영', '김판다'],
        '점수': [680, 680, 880, 620, 750]}
df = pd.DataFrame(data)
df
# Out:
#    회차   이름   점수
# 0   1  김판다  680
# 1   1  김판다  680
# 2   1  강승주  880
# 3   2  조민영  620
# 4   2  김판다  750

# %%
# 코드 6-39. 중복 데이터 확인
df.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
# 코드 6-40. 중복 데이터 삭제
df.drop_duplicates()
# Out:
#    회차   이름   점수
# 0   1  김판다  680
# 2   1  강승주  880
# 3   2  조민영  620
# 4   2  김판다  750

# %% [markdown]
# #### 6.5.3 중복 데이터 처리 함수의 활용
#
# 📌 `drop_duplicates` 함수의 다양한 활용
# - `subset` 매개변수로 **기준 열 지정** → 다양한 필터링 가능

# %%
# 코드 6-41. df의 이름 열로만 중복을 결정해 중복 데이터 삭제
df.drop_duplicates('이름')
# Out:
#    회차   이름   점수
# 0   1  김판다  680
# 2   1  강승주  880
# 3   2  조민영  620

# %%
# 코드 6-42. keep을 활용해 각 사람의 마지막 성적을 필터링
df.drop_duplicates('이름', keep='last')
# Out:
#    회차   이름   점수
# 2   1  강승주  880
# 3   2  조민영  620
# 4   2  김판다  750

# %%
# 코드 6-43. keep을 활용해 시험에 한 번만 응시한 사람의 성적만 필터링
df.drop_duplicates('이름', keep=False)
# Out:
#    회차   이름   점수
# 2   1  강승주  880
# 3   2  조민영  620

# %% [markdown]
# ### 6.6. 자료형 변환과 소수점 처리
#
# [표 6-6] 여러 가지 자료형
#
# | 자료형 | 뜻 |
# | :--- | :--- |
# | **`float`** | 실수 (부동 소수점) |
# | **`int`** | 정수 |
# | **`str`** | 문자열 |
# | **`bool`** | 불 (True 또는 False) |
# | **`datetime`** | 시계열 (날짜와 시간) |
# | **`category`** | 범주형 |
#
# <br>

# %% [markdown]
# #### 6.6.1. 여러 가지 자료형으로 변환하기(astype)
#
# ⭐ 판다스 `astype`
#
# 데이터 프레임이나 시리즈의 자료형을 변환하는 함수
#
# <br>
#
# ⭐ `astype` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.astype(dtype)
# ```
#
# - **dtype**: 변환할 자료형을 지정한다. 매퍼를 입력하면 열마다 서로 다른 자료형으로 변환한다.
#
# <br>

# %%
# 코드 6-44. 자료형 변환 실습 예제 코드
import pandas as pd
data1 = [[8.2, 9, '17', '1'], [7.1, 9, '18', '2'],
         [9.3, 7, '18', '3'], [7.8, 7, '19', '-']]
df1 = pd.DataFrame(data1, columns=['실수', '정수', '문자열1', '문자열2'])
df1
# Out:
#     실수  정수 문자열1 문자열2
# 0  8.2   9   17    1
# 1  7.1   9   18    2
# 2  9.3   7   18    3
# 3  7.8   7   19    -

# %%
# 코드 6-45. df1의 자료형을 dtypes 속성으로 파악하기
df1.dtypes
# Out:
# 실수      float64
# 정수        int64
# 문자열1     object
# 문자열2     object
# dtype: object

# %%
# 코드 6-46. df1의 자료형을 문자열(str)로 변환하기
df1.astype('str')
# Out:
#     실수 정수 문자열1 문자열2
# 0  8.2  9   17    1
# 1  7.1  9   18    2
# 2  9.3  7   18    3
# 3  7.8  7   19    -

# %%
# 코드 6-47. 코드 6-46의 결과 자료형 확인하기
df1.astype('str').dtypes
# Out:
# 실수      object
# 정수      object
# 문자열1    object
# 문자열2    object
# dtype: object

# %%
# 코드 6-48. 매퍼를 입력해 열마다 다른 자료형으로 변환한 뒤 자료형 확인하기
df1.astype({'실수': 'int', '정수': 'str'}).dtypes
# Out:
# 실수       int64
# 정수      object
# 문자열1    object
# 문자열2    object
# dtype: object

# %%
# 코드 6-49. 실수 열을 정수 자료형으로 변환하기
df1['실수'].astype('int')
# Out:
# 0    8
# 1    7
# 2    9
# 3    7
# Name: 실수, dtype: int64

# %% [markdown]
# #### 6.6.2. 수치형으로 변환하기(to_numeric)
#
# <img src=https://i.postimg.cc/KcM7ydPL/image.png, width=600>
#
# ⭐ 판다스 `to_numeric`
#
# 단일 값 또는 1차원 배열의 자료형을 수치형으로 변환하는 함수
#
# <br>
#
# ⭐ `to_numeric` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# pd.to_numeric(arg, errors='raise')
# ```
#
# - **arg**: 변환할 대상을 지정한다. 스칼라 또는 1차원 배열을 입력한다.
# - **errors**: 이 함수를 사용하는 가장 큰 이유이며 변환할 수 없는 데이터를 처리하는 방법을 지정한다. 변환할 수
# 없는 데이터를 만났을 때 기본값인 'raise'는 에러가 발생한다. 'coerce'는 변환할 수 없는 데이터를 NaN으로
# 변환하고 변환을 완료한다. 'ignore'는 변환하지 않고 원본을 유지하며, 변환하는 다른 데이터도 전혀 변환하지
# 않는다. 대부분은 'coerce'를 사용한다
#
# <br>

# %%
# 코드 6-50. 수치형으로 바꿀 수 없는 문자열이 포함되었을 때 수치형으로 변환
pd.to_numeric(df1['문자열2'], errors='coerce')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# Name: 문자열2, dtype: float64

# %%
# 코드 6-51. 데이터 프레임 전체에 to_numeric 함수 적용하기
df1.apply(pd.to_numeric, errors='coerce')
# Out:
#     실수  정수  문자열1  문자열2
# 0  8.2   9    17   1.0
# 1  7.1   9    18   2.0
# 2  9.3   7    18   3.0
# 3  7.8   7    19   NaN

# %% [markdown]
# #### 6.6.3. 소수점 처리하기
#
# <img src=https://i.postimg.cc/mgFLQSbm/image.png, width=600>
#
# ⭐ 판다스 `round`
#
# 데이터 프레임이나 시리즈를 반올림하는 함수
#
# <br>
#
# ⭐ `round` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.round(decimals=0)
# ```
#
# - **decimals**: 소수점 자릿수를 지정한다. 기본값은 0이고 소수점 첫째 자리에서 반올림을 수행한다.
#
# <br>

# %%
# 코드 6-52. 반올림 실습 예제 코드
import pandas as pd
data2 = [[1.025, 2.249], [3.923, 4.035], [5.418, 6.736]]
df2 = pd.DataFrame(data2, index=list('ABC'), columns=['col1', 'col2'])
df2
# Out:
#     col1   col2
# A  1.025  2.249
# B  3.923  4.035
# C  5.418  6.736

# %%
# 코드 6-53. df2를 소수점 셋째 자리에서 반올림
df2.round(2)
# Out:
#    col1  col2
# A  1.02  2.25
# B  3.92  4.04
# C  5.42  6.74

# %%
# 코드 6-54. 출력 옵션으로 소수점 둘째 자리까지 표시
pd.options.display.float_format = '{:.2f}'.format
df2
# Out:
#    col1  col2
# A  1.02  2.25
# B  3.92  4.04
# C  5.42  6.74

# %% [markdown]
# ### 6.7. 데이터 치환과 매핑

# %% [markdown]
# #### 6.7.1. 데이터 치환(replace)
#
# <img src=https://i.postimg.cc/yNpCtgYS/image.png, width=600>
#
# ⭐ 판다스 `replace`
#
# 데이터 프레임이나 시리즈의 각 셀을 치환하는 함수
#
# <br>
#
# ⭐ `replace` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.replace(to_replace=None, value=None, regex=False)
# ```
#
# - **to_replace**: 이전 값을 입력한다. 이전 값과 새로운 값의 매퍼도 입력 가능하다.
# - **value**: 새로운 값을 입력한다.
# - **regex**: 정규 표현식 사용 여부를 지정한다.
#
# <br>

# %%
# 코드 6-55. 치환 실습 예제 코드
data = {'홈팀': ['서독', '대한민국', '브라질', '소련', '대한민국'],
         '원정팀': ['대한민국', '서독', '소련', '브라질', '브라질'],
         '홈팀골': [3, 1, 4, 2, 0], '원정팀골': [0, 2, 1, 2, 2]}
data1 = {'old': ['서독', '소련'], 'new': ['독일', '러시아']}

df = pd.DataFrame(data)
df1 = pd.DataFrame(data1)
df
# Out:
#      홈팀   원정팀  홈팀골  원정팀골
# 0    서독  대한민국    3     0
# 1  대한민국    서독    1     2
# 2   브라질    소련    4     1
# 3    소련   브라질    2     2
# 4  대한민국   브라질    0     2

# %%
# 코드 6-56. 서독을 독일로 치환
df.replace('서독', '독일')
# Out:
#      홈팀   원정팀  홈팀골  원정팀골
# 0    독일  대한민국    3     0
# 1  대한민국    독일    1     2
# 2   브라질    소련    4     1
# 3    소련   브라질    2     2
# 4  대한민국   브라질    0     2

# %%
# 코드 6-57. regex=True로 셀의 일부를 치환
df.replace('대한민', '한', regex=True)
# Out:
#     홈팀  원정팀  홈팀골  원정팀골
# 0   서독   한국    3     0
# 1   한국   서독    1     2
# 2  브라질   소련    4     1
# 3   소련  브라질    2     2
# 4   한국  브라질    0     2

# %%
# 코드 6-58. 서독과 소련을 EU로 치환
df.replace(['서독', '소련'], 'EU')
# Out:
#      홈팀   원정팀  홈팀골  원정팀골
# 0    EU  대한민국    3     0
# 1  대한민국    EU    1     2
# 2   브라질    EU    4     1
# 3    EU   브라질    2     2
# 4  대한민국   브라질    0     2

# %%
# 코드 6-59. 서독을 독일로 치환하고 소련을 러시아로 치환
df.replace({'서독': '독일', '소련': '러시아'})
# Out:
#      홈팀   원정팀  홈팀골  원정팀골
# 0    독일  대한민국    3     0
# 1  대한민국    독일    1     2
# 2   브라질   러시아    4     1
# 3   러시아   브라질    2     2
# 4  대한민국   브라질    0     2

# %%
# 코드 6-60. 데이터 프레임으로 매퍼(시리즈)를 만들어 치환하기
m = df1.set_index('old')['new']
df.replace(m)
# Out:
#      홈팀   원정팀  홈팀골  원정팀골
# 0    독일  대한민국    3     0
# 1  대한민국    독일    1     2
# 2   브라질   러시아    4     1
# 3   러시아   브라질    2     2
# 4  대한민국   브라질    0     2

# %% [markdown]
# #### 6.7.2. 매핑하기(map)
#
# <img src=https://i.postimg.cc/zBNTmBtX/image.png, width=600>
#
# ⭐ 판다스 `map`
#
# 시리즈나 인덱스 클래스의 매핑을 수행하는 함수
#
# <br>
#
#
# ⭐ `map` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# s.map(func)
# ```
#
# - **func**: 함수, 시리즈, 딕셔너리 등의 매퍼를 입력한다.
#
# <br>

# %%
# 코드 6-61. 매핑 실습 예제 코드
import pandas as pd
s = pd.Series(['사과', '바나나', '바나나', '포도', '사과'])
s
# Out:
# 0     사과
# 1    바나나
# 2    바나나
# 3     포도
# 4     사과
# dtype: object

# %%
# 코드 6-62. 사과는 '0', 바나나는 '1', 포도는 '2'로 매핑하기
dict1 = {'사과': '0', '바나나': '1', '포도': '2'}
s.map(dict1)
# Out:
# 0    0
# 1    1
# 2    1
# 3    2
# 4    0
# dtype: object

# %% [markdown]
# #### 6.7.3. replace 함수와 map 함수의 차이

# %%
# 코드 6-63. replace 함수로 코드 6-62 수행하기
s.replace(dict1)
# Out:
# 0    0
# 1    1
# 2    1
# 3    2
# 4    0
# dtype: object

# %%
# 코드 6-64. 사과만 '0'으로 매핑하기
dict2 = {'사과': '0'}
s.map(dict2)
# Out:
# 0      0
# 1    NaN
# 2    NaN
# 3    NaN
# 4      0
# dtype: object

# %%
# 코드 6-65. 코드 6-64를 replace 함수로 수행해 map 함수와의 차이 확인하기
s.replace(dict2)
# Out:
# 0      0
# 1    바나나
# 2    바나나
# 3     포도
# 4      0
# dtype: object

# %%
# 코드 6-66. 사과는 '0' 나머지는 전부 '1'로 매핑하기
s.map(dict2).fillna('1')
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# dtype: object

# %% [markdown]
# ### 엑셀 예제 5.  미국 레스토랑 고객의 팁 데이터 정제하기

# %%
# 코드 6-67. 미국 레스토랑 고객의 팁 엑셀 파일에서 데이터 프레임 불러오기
import pandas as pd
pd.options.display.max_rows = 6 # 6행까지만 출력
url2 = 'https://github.com/panda-kim/book1/blob/main/09tips.xlsx?raw=true'
df_tips = pd.read_excel(url2)
df_tips
# Out:
#      total_bill  tip  gender smoker   day    time  size
# 0         16.99    -  Female     No   Sun   Lunch     2
# 1         10.34 1.66    Male     No   Sun  Dinner     3
# 2         21.01 3.50    Male    NaN   Sun  Dinner     3
# ..          ...  ...     ...    ...   ...     ...   ...
# 241       22.67    2    Male    NaN   Sat  Dinner     2
# 242       17.82 1.75    Male     No   Sat  Dinner     2
# 243       18.78    3  Female    NaN  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 코드 6-68. info 함수로 데이터 프레임 확인하기
df_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    object
#  2   gender      244 non-null    object
#  3   smoker      231 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 13.5+ KB

# %%
# 코드 6-69. tip 열을 실수 자료형으로 변환하기
df_tips['tip'] = pd.to_numeric(df_tips['tip'], errors='coerce')
df_tips
# Out:
#      total_bill  tip  gender smoker   day    time  size
# 0         16.99  NaN  Female     No   Sun   Lunch     2
# 1         10.34 1.66    Male     No   Sun  Dinner     3
# 2         21.01 3.50    Male    NaN   Sun  Dinner     3
# ..          ...  ...     ...    ...   ...     ...   ...
# 241       22.67 2.00    Male    NaN   Sat  Dinner     2
# 242       17.82 1.75    Male     No   Sat  Dinner     2
# 243       18.78 3.00  Female    NaN  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 코드 6-70. time 열의 Lunch를 0, Dinner를 1로 매핑하기
m1 = {'Lunch': 0, 'Dinner': 1}
df_tips['time'] = df_tips['time'].map(m1)
df_tips
# Out:
#      total_bill  tip  gender smoker   day  time  size
# 0         16.99  NaN  Female     No   Sun     0     2
# 1         10.34 1.66    Male     No   Sun     1     3
# 2         21.01 3.50    Male    NaN   Sun     1     3
# ..          ...  ...     ...    ...   ...   ...   ...
# 241       22.67 2.00    Male    NaN   Sat     1     2
# 242       17.82 1.75    Male     No   Sat     1     2
# 243       18.78 3.00  Female    NaN  Thur     1     2
#
# [244 rows x 7 columns]

# %%
# 코드 6-71. smoker 열의 결측값을 여자일때 No, 남자일때는 Yes로 대체하기
m2 = {'Female': 'No', 'Male': 'Yes'}
df_tips['smoker'] = df_tips['smoker'].fillna(df_tips['gender'].map(m2))
df_tips
# Out:
#      total_bill  tip  gender smoker   day  time  size
# 0         16.99  NaN  Female     No   Sun     0     2
# 1         10.34 1.66    Male     No   Sun     1     3
# 2         21.01 3.50    Male    Yes   Sun     1     3
# ..          ...  ...     ...    ...   ...   ...   ...
# 241       22.67 2.00    Male    Yes   Sat     1     2
# 242       17.82 1.75    Male     No   Sat     1     2
# 243       18.78 3.00  Female     No  Thur     1     2
#
# [244 rows x 7 columns]

# %%
# 코드 6-72. info 함수로 df_tips의 자료형 확인
df_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         218 non-null    float64
#  2   gender      244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    int64
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 13.5+ KB

# %%
# 코드 6-73. 결과를 엑셀 파일로 저장
df_tips.to_excel('ch06_tips.xlsx', index=False)
