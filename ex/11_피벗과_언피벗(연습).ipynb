# %% [markdown]
# ## Chapter 11. 피벗과 언피벗

# %%
# 버전 안내
import pandas as pd
print(f'교재 권장 버전: Pandas 2.2.2')
print(f'현재 실행 버전: Pandas {pd.__version__}')
# Out:
# 교재 권장 버전: Pandas 2.2.2
# 현재 실행 버전: Pandas 2.2.2

# %% [markdown]
# ### 11.1. 피벗 테이블

# %% [markdown]
# #### 11.1.1. 피벗 테이블을 사용하는 이유
#
# <img src=https://i.postimg.cc/5y6CZgr8/image.png, width=600>

# %% [markdown]
# #### 11.1.2. 피벗 테이블과 집계 함수
#
# - **집계 함수 = 여러 값을 하나로 요약하는 함수**
#
# - 피벗 테이블은 **여러 값을 한 셀에 담아야 하므로 집계 함수 필수**

# %% [markdown]
# #### 11.1.3. 피벗 테이블 생성하기(pivot_table)
#
# <img src=https://i.postimg.cc/63Z8RLQf/image.png, width=600>
#
# ⭐ 판다스 `pivot_table`
#
# 원시 데이터로 피벗 테이블을 생성하는 함수
#
# <br>
#
# ⭐ `pivot_table` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.pivot_table(values=None, index=None, columns=None, aggfunc='mean')
# ```
#
# - **values**: 집계할 대상 열을 지정한다. 그림은 점수 열을 집계했다.
#
# - **index**: 행으로 구분할 그룹을 나누는 기준 열을 지정한다. 그림은 피벗 테이블의 행에서 반이 구분된다.
#
# - **columns**: 열로 구분할 그룹을 나누는 기준 열을 지정한다. 그림은 피벗 테이블의 열에서 성별이 구분된다.
#
# - **aggfunc**: 그룹의 차원을 축소할 집계 함수를 지정한다. 기본값은 'mean'으로 그룹의 평균을 구해 차원을 축소한다.
#
# <img src=https://i.postimg.cc/XJ9vXj2s/image.png, width=600>
#
# <br>

# %%
# 코드 11-1. 다양한 피벗 테이블을 생성 실습 예제 코드
import pandas as pd
pd.options.display.float_format = '{:.1f}'.format # 소수점 첫째 자리 출력
data = [['김판다', '남', 'A', 97, '1등', '수시'],
        ['강승주', '여', 'A', 88, '2등', '정시'],
        ['권보아', '여', 'A', 78, '3등', '정시'],
        ['조민영', '여', 'B', 64, '3등', '수시'],
        ['박상현', '남', 'B', 84, '2등', '수시'],
        ['송중기', '남', 'B', 89, '1등', '수시'],
        ['최진환', '남', 'C', 87, '3등', '정시'],
        ['장범준', '남', 'C', 92, '2등', '정시'],
        ['안지선', '여', 'C', 99, '1등', '수시']]
col = ['이름', '성별', '반', '점수', '반등수', '비고']

data1 = {'제품': ['A', 'B', 'A', 'B', 'B', 'A'],
         '판매량': [float('nan'), 2, 3, 4, float('nan'), 6]}

df = pd.DataFrame(data, columns=col)
df1 = pd.DataFrame(data1)
df
# Out:
#     이름 성별  반  점수 반등수  비고
# 0  김판다  남  A  97  1등  수시
# 1  강승주  여  A  88  2등  정시
# 2  권보아  여  A  78  3등  정시
# 3  조민영  여  B  64  3등  수시
# 4  박상현  남  B  84  2등  수시
# 5  송중기  남  B  89  1등  수시
# 6  최진환  남  C  87  3등  정시
# 7  장범준  남  C  92  2등  정시
# 8  안지선  여  C  99  1등  수시

# %%
# 코드 11-2. df를 반(index)과 성별(columns)로 구분해 평균 점수 구하기

# %%
# 코드 11-3. 코드 11-2에서 매개변수 aggfunc의 기본값이 'mean'이기에 생략이 가능

# %% [markdown]
# #### 11.1.4. 복수의 인수를 입력해 피벗 테이블 만들기
#
# - 네 가지 매개변수 모두 **복수의 인수 입력 가능**
# - 복수의 인수는 **리스트로 묶어 전달**

# %%
# 코드 11-4. df에서 반과 성별(index), 비고(columns)로 나누어 평균 점수 구하기

# %%
# 코드 11-5. df에서 반(index)과 성별(columns)로 나누어 평균 점수와 인원수 구하기

# %% [markdown]
# #### 11.1.5. 인수로 함수를 입력하는 방법
#
# 📌 **pivot_table의 aggfunc에 집계 함수를 입력하는 방법**
#
# - **시리즈에 적용이 가능한 함수**만 가능
# - 인수로 넣을 때는 **메서드가 아닌 함수 형태**로 입력
#   - 예: `s.count()` X → `pd.Series.count` O
# - 자주 쓰는 함수는 **문자열로도 호출 가능**
#   - `'count'`, `'sum'`, `'max'` 등

# %% [markdown]
# #### 11.1.6. 그룹화에만 적용되는 집계 함수(first, last)
#
# 📌 **first / last 집계 함수의 특징**
#
# - **first·last는 그룹을 나눌 때만 사용 가능한 특별한 집계 함수**
#
#  - pivot_table, groupby, resample 등 그룹을 나누는 함수와 함께 사용할 때만 동작
#
#   - **first** → 각 그룹에서 **null이 아닌 첫 번째 값** 반환
#
#   - **last** → 각 그룹에서 **null이 아닌 마지막 값** 반환

# %% [markdown]
# 실습에 쓰일 df1 확인
#
# |    | 제품   |   판매량 |
# |---:|:-------|---------:|
# |  0 | A      |      NaN |
# |  1 | B      |        2 |
# |  2 | A      |        3 |
# |  3 | B      |        4 |
# |  4 | B      |      NaN |
# |  5 | A      |        6 |

# %%
# 코드 11-6. df1에서 제품별로 첫 번째 판매량을 집계

# %%
# 코드 11-7. df1에서 제품별로 마지막 판매량을 집계

# %%
# 코드 11-8. df에서 반(index)과 성별(columns)로 나누어 1등의 명단 생성하기

# %% [markdown]
# #### 11.1.7. 문자열 피벗(pivot)
#
# <img src=https://i.postimg.cc/g0tYJwqV/image.png, width=600>
#
# ⭐ 판다스 `pivot`
#
# 집계 함수 없이 피벗 테이블을 만드는 함수. 주로 문자열 피벗에 쓰인다.
#
# <br>
#
# ⭐ `pivot` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.pivot(index=None, columns=None, values=None)
# ```
#
#
# - **index**: 행으로 구분할 그룹을 나누는 기준 열을 지정한다. 그림은 행에서 등수가 구분된다.
#
# - **columns**: 열로 구분할 그룹을 나누는 기준 열을 지정한다. 그림은 열에서 반이 구분된다.
#
# - **values**:피벗할 대상 열을 지정한다. 그림은 이름 열을 피벗했다.
#
# <br>

# %%
# 코드 11-9. df에서 pivot 함수로 반(index), 반등수(columns)로 나누어 이름을 피벗

# %% [markdown]
# #### 11.1.8. 빈도수를 집계하는 교차표 만들기(crosstab)
#
# <img src=https://i.postimg.cc/t41kfwv1/image.png, width=600>
#
# ⭐ 판다스 `crosstab`
#
# 빈도수를 집계해 교차표를 생성하는 함수이다.
#
# <br>
#
# ⭐ `crosstab` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# pd.crosstab(index, columns)
# ```
#
# - **index**: 행으로 그룹화할 기준 열을 입력한다.
#
# - **columns**: 열로 그룹화할 기준 열을 입력한다.
#
# <br>

# %%
# 코드 11-10. crosstab 함수 실습 예제 코드
data = {'반': ['A', 'A', 'A', 'B', 'B', 'B'],
        '성별': ['남', '여', '여', '여', '남', '남']}
df = pd.DataFrame(data)
df
# Out:
#    반 성별
# 0  A  남
# 1  A  여
# 2  A  여
# 3  B  여
# 4  B  남
# 5  B  남

# %%
# 코드 11-11. df에서 반(index), 성별(columns)을 나누어 crosstab 함수로 인원수 집계

# %% [markdown]
# ### 엑셀 예제 14. 타이타닉 침몰 사고에서 과연 여성과 아이를 먼저 구조했을까?

# %%
# 코드 11-12. 타이타닉 엑셀 파일에서 데이터 프레임 불러오기
import pandas as pd
pd.options.display.max_rows = 6 # 6행까지만 출력
pd.options.display.float_format = '{:.3f}'.format # 소수점 셋째 자리 출력
url1 = 'https://github.com/panda-kim/book1/blob/main/05titanic.xlsx?raw=true'
df_titanic = pd.read_excel(url1)
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# ..           ...       ...     ...
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.000      1
# 2                               Heikkinen, Miss. Laina  female 26.000      0
# ..                                                 ...     ...    ...    ...
# 888           Johnston, Miss. Catherine Helen "Carrie"  female    NaN      1
# 889                              Behr, Mr. Karl Howell    male 26.000      0
# 890                                Dooley, Mr. Patrick    male 32.000      0
#
#      Parch            Ticket   Fare Cabin Embarked
# ...

# %%
# 코드 11-13. 성별(index)과 객실 등급(columns)으로 나누어 생존율 구하기
# df_titanic을 대상으로 구해, 결과는 df_result로 지정

# %%
# 코드 11-14. df_result의 열 순서를 male, female으로 변경하고 인덱스명 삭제

# %%
# 코드 11-15. 객실 등급(columns)으로 나누어 15세 이하의 생존율을 구하기
# df_titanic에서 15세 이하의 생존율을 구해 df_child로 지정

# %%
# 코드 11-16. df_result에 15세 이하의 생존율을 열로 생성하기

# %%
# 코드 11-17. df_result를 시각화
colors = ['#111558', '#3496c6', '#cce8c8'] # 헥스 코드로 색상 설정

# %% [markdown]
# ### 11.2. 언피벗

# %% [markdown]
# #### 11.2.1. 언피벗이 필요한 이유
#
# <img src=https://i.postimg.cc/5y6CZgr8/image.png, width=600>
#
# 📌 **언피벗이 필요한 이유**
#
# - 피벗된 데이터를 **원시 데이터 형태로 복원**해 관리·추가가 쉬워진다
# - 피벗 테이블만으로는 **데이터 추가·확장·재구조화가 어렵다**
# - 한 방향으로 요약된 피벗 테이블은 **다른 방향으로 다시 피벗하기 어려움**
# - 언피벗을 하면 **행 단위 정보가 살아나** 원하는 형태로 **새로운 피벗 테이블 생성 가능**
# - 판다스 언피벗 방법
#   - **stack + reset_index**
#   - **melt**

# %% [markdown]
# #### 11.2.2. stack 함수로 언피벗
#
# - **stack + reset_index** 이미 학습한 두 함수를 조합해 **언피벗을 수행한다.**

# %%
# 코드 11-18. stack과 reset_index로 언피벗 실습 예제 코드
import pandas as pd
pd.options.display.max_rows = 10 # 10행까지만 출력 코드
data1 = {'1등': {'1회차': '김판다', '2회차': '박효신', '3회차': '김판다'},
         '2등': {'1회차': '권보아', '2회차': '권보아', '3회차': '박효신'},
         '3등': {'1회차': '박효신', '2회차': '강승주', '3회차': '김범수'}}
df = pd.DataFrame(data1)
df
# Out:
#       1등   2등   3등
# 1회차  김판다  권보아  박효신
# 2회차  박효신  권보아  강승주
# 3회차  김판다  박효신  김범수

# %%
# 코드 11-19. stack과 reset_index로 언피벗하기
# df를 언피벗

# %%
# 코드 11-20. 코드 11-19의 결과에서 열 이름을 설정해 변수 df1으로 지정

# %%
# 코드 11-21. df1으로 각 사람의 입상 빈도수를 집계

# %% [markdown]
# #### 11.2.3. melt 함수로 언피벗
#
# <img src=https://i.postimg.cc/2jGDGcK4/image.png, width=600>
#
# ⭐ 판다스 `melt`
#
# 데이터 프레임의 언피벗을 수행하는 함수
#
# <br>
#
# ⭐ `melt` 함수의 주요 매개변수와 인수, 기본값
#
# ```python
# df.melt(id_vars=None, value_vars=None, var_name='variable', value_name='value')
# ```
# - **id_vars**: 인덱스처럼 언피벗하지 않고 별도의 열로 처리될 열을 지정한다.
#
# - **value_vars**: 언피벗을 수행할 열을 지정한다. 기본값으로 id_vars에 지정되지 않은 모든 열을 언피벗한다.
#
# - **var_name**: 언피벗 후 생성되는 variable 열의 이름을 변경한다.
#
# - **value_name**: 언피벗 후 생성되는 value 열의 이름을 변경한다.
#
# <br>

# %%
# 코드 11-22. melt 함수 실습 예제 코드
import pandas as pd
data = {'반': ['A', 'B', 'C'], '남': [10, 20, 15], '여': [30, 40, 35]}
df = pd.DataFrame(data)
df1 = df.set_index('반')
df
# Out:
#    반   남   여
# 0  A  10  30
# 1  B  20  40
# 2  C  15  35

# %%
# 코드 11-23. df에서 melt 함수로 언피벗하기

# %%
# 코드 11-24. value_vars를 생략해도 코드 11-23과 같은 결과를 얻는다.

# %%
# 코드 11-25. 언피벗 결과에서 열 이름 설정하기

# %% [markdown]
# #### 11.2.4. stack 함수와 melt 함수의 언피벗 수행의 차이점
#
# - **melt는 인덱스를 보존하지 않음** → 인덱스가 중요하면 **stack + reset_index**
# - 두 기법은 **정렬 결과가 다름**
# - 둘 다 언피벗 가능하므로 **상황·취향에 따라 선택**

# %% [markdown]
# ### 엑셀 예제 15. 피벗 테이블로 보존된 마트의 매출 데이터로 다양한 집계하기

# %%
# 코드 11-26. 첫번째 시트만 데이터 프레임으로 불러오기
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format # 소수점 둘째 자리 출력
pd.options.display.max_rows = 6 # 6행까지만 출력
url2 = 'https://github.com/panda-kim/book1/blob/main/17mart.xlsx?raw=true'
df1 = pd.read_excel(url2)
df1
# Out:
#                제품      강남점      서초점      송파점      노원점      은평점      금천점  \
# 0     종합어묵 (300g)  1930000  1350000   630000   420000  1360000  1370000
# 1    유기농떡튀밥 (40g)   320000   380000   490000  1320000  1380000  1350000
# 2    염장다시마 (400g)  1310000  1700000   670000   640000  1180000  1840000
# ..            ...      ...      ...      ...      ...      ...      ...
# 197   생선가스 (300g)   850000  1440000   200000   300000   410000   300000
# 198    게맛살 (178g)  1240000   380000  1680000  1500000   730000   550000
# 199   멸치가루 (120g)   250000  1170000  1980000   340000  1760000   550000
#
#         신도림점   용인 죽전점  용인 수지점   수원 영통점   인천 주안점   인천 검단점     동인천점      분당점  \
# 0    1880000  1210000  710000  1130000   280000  1260000  1480000   960000
# 1    1280000   860000  720000  1500000  1090000  1850000   420000   570000
# 2     910000  1080000  240000  1510000   660000  1420000   260000  1440000
# ..       ...      ...     ...      ...      ...      ...      ...      ...
# ...

# %%
# 코드 11-27. 첫 번째 시트 언피벗하기
df1.melt('제품', var_name='지점', value_name='매출')
# Out:
#                 제품      지점       매출
# 0      종합어묵 (300g)     강남점  1930000
# 1     유기농떡튀밥 (40g)     강남점   320000
# 2     염장다시마 (400g)     강남점  1310000
# ...            ...     ...      ...
# 3397   생선가스 (300g)  부천 옥길점  1300000
# 3398    게맛살 (178g)  부천 옥길점  1610000
# 3399   멸치가루 (120g)  부천 옥길점  1030000
#
# [3400 rows x 3 columns]

# %%
# 코드 11-28. 첫 번째와 두 번째 시트를 언피벗하고 연결
# 첫 번째 시트 언피벗
df1 = pd.read_excel(url2)
df1 = df1.melt('제품', var_name='지점', value_name='매출')
df1['날짜'] = '2023-08' # 각 시트에 맞게 날짜 데이터 생성

# 두 번째 시트 언피벗
df2 = pd.read_excel(url2, sheet_name=1)
df2 = df2.melt('제품', var_name='지점', value_name='매출')
df2['날짜'] = '2023-09' # 각 시트에 맞게 날짜 데이터 생성

# df1과 df2를 concat로 연결하고, 결과를 변수 df_mart로 지정
df_mart = pd.concat([df1, df2]).reset_index(drop=True)
df_mart
# Out:
#                 제품      지점       매출       날짜
# 0      종합어묵 (300g)     강남점  1930000  2023-08
# 1     유기농떡튀밥 (40g)     강남점   320000  2023-08
# 2     염장다시마 (400g)     강남점  1310000  2023-08
# ...            ...     ...      ...      ...
# 6797   생선가스 (300g)  부천 옥길점  1490000  2023-09
# 6798    게맛살 (178g)  부천 옥길점  1740000  2023-09
# 6799   멸치가루 (120g)  부천 옥길점   410000  2023-09
#
# [6800 rows x 4 columns]

# %%
# 코드 11-29. df_mart에 지점구분 시트를 병합

# %%
# 코드 11-30. df_mart에 제품구분 시트를 병합

# %%
# 코드 11-31. 지역(index)과 날짜(columns)를 구분해 매출 합계 구하기

# %%
# 코드 11-32. 청과 제품군의 총매출량을 월별로 직영점과 비직영점 비교하기
